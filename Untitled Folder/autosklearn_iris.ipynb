# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], random_state=0)
print("X_train 크기: {}".format(X_train.shape))
print("y_train 크기: {}".format(y_train.shape))
# Out:
# X_train 크기: (112, 4)
# y_train 크기: (112,)

# %%
import pandas as pd
import numpy as np
import random as rnd
import os
import sys

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn import preprocessing

# %%
df = pd.DataFrame(iris_dataset.data, columns = iris_dataset.feature_names)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %%
df["target"] = iris_dataset.target_names[iris_dataset.target]
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
# ...

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
import autosklearn.classification
import sklearn.model_selection
import sklearn.metrics
C = "Categorical"
N = "Numerical"
label_name = "target"
feature_dict = {
    'sepal length (cm)': N,
    'sepal width (cm)': N,
    'petal length (cm)': N,
    'petal width (cm)': N,
}
feat_type = list(feature_dict.values())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# target               150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train1, y_train1)

y_pred1 = classifier.predict(X_test1)

# Summary of the predictions made by the classifier
print(classification_report(y_test1, y_pred1))
print(confusion_matrix(y_test1, y_pred1))

from sklearn.metrics import accuracy_score
print('Test accuracy is {:.2f}%'.format(accuracy_score(y_pred1,y_test1)*100,))
# Out:
#              precision    recall  f1-score   support
#
#      setosa       1.00      1.00      1.00        11
#  versicolor       1.00      0.92      0.96        13
#   virginica       0.86      1.00      0.92         6
#
# avg / total       0.97      0.97      0.97        30
#
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
# Test accuracy is 96.67%

# %%
automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=120, per_run_time_limit=30
)

# %%
X_train1.shape, y_train1.shape, X_test1.shape, y_test1.shape
# Out:
# ((120, 4), (120,), (30, 4), (30,))

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((112, 4), (112,), (38, 4), (38,))

# %%
automl.fit(X_train.copy(), y_train.copy(), feat_type=feat_type, dataset_name='Iris')
print(automl.show_models())
predictions = automl.predict(X_test)
print("Accuracy score", sklearn.metrics.accuracy_score(y_test, predictions))
# Out:
# [(0.580000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'liblinear_svc_preprocessor', 'rescaling:__choice__': 'standardize', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.7983157215145903, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 4, 'classifier:random_forest:min_samples_split': 15, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:liblinear_svc_preprocessor:C': 0.4971515945303584, 'preprocessor:liblinear_svc_preprocessor:dual': 'False
# ...

# %%
y_test
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 1])

# %%
import pickle
filename = "automodel_iris.sav"
pickle.dump(automl, open(filename, "wb"))

# %%
# Importing metrics for evaluation
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred_log = logreg.predict(X_test)
acc_log_train = round(logreg.score(X_train, y_train) * 100, 4)
acc_log_test = round(logreg.score(X_test, y_test) * 100, 4)

print("Train acc : ",acc_log_train)
print("Test acc : ",acc_log_test)
# Out:
# Train acc :  94.6429
# Test acc :  86.8421

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        13
#           1       1.00      0.94      0.97        16
#           2       0.90      1.00      0.95         9
#
# avg / total       0.98      0.97      0.97        38

# %%
acc_auto_test = round(sklearn.metrics.accuracy_score(y_test, predictions) * 100 ,4)
print("Test acc : ",acc_auto_test)
# Out:
# Test acc :  100.0

# %%
coeff_log=pd.DataFrame(df.columns)
coeff_log.columns = ["Feature"]
coeff_log["Correlation"] = pd.Series(logreg.coef_[0])
coeff_log.sort_values(by="Correlation", ascending=False)
# Out:
#              Feature  Correlation
# 1   sepal width (cm)     1.341157
# 0  sepal length (cm)     0.403857
# 3   petal width (cm)    -0.965028
# 2  petal length (cm)    -2.131876
# 4             target          NaN

# %%
svc = SVC()
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
acc_svc_train = round(svc.score(X_train, y_train) * 100, 4)
acc_svc_test = round(svc.score(X_test, y_test) * 100, 4)
print("Train acc : ",acc_svc_train)
print("Test acc : ",acc_svc_test)
# Out:
# Train acc :  98.2143
# Test acc :  97.3684

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
acc_knn_train = round(knn.score(X_train, y_train) * 100, 4)
acc_knn_test = round(knn.score(X_test, y_test) * 100, 4)
print("Train acc : ",acc_knn_train)
print("Test acc : ",acc_knn_test)
# Out:
# Train acc :  97.3214
# Test acc :  97.3684

# %%
df.plot(kind="box", sharex=False, sharey = False)

# %%
df.hist(edgecolor="black", linewidth=1.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d095208>,
# ...
#       dtype=object)

# %%
df.boxplot(by="target",figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d082588>,
# ...
#       dtype=object)

# %%
sns.violinplot(data=df, x="target", y ="petal width (cm)")
sns.violinplot(data=df, x="target", y ="petal width (cm)")

# %%
loaded_model = pickle.load(open(filename, "rb"))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-509618f14bfa> in <module>()
# ----> 1 loaded_model = pickle.load(open(filename, "rb"))
#       2 result = loaded_model.score(X_test, y_test)
#       3 print(result)
#
# NameError: name 'pickle' is not defined

# %%
automl = autosklearn.classification.AutoSklearnClassifier(
            time_left_for_this_task=120, per_run_time_limit=30
        )

# %%
        # Set Data Set
        C = "Categorical"
        N = "Numerical"
        label_name = "target"
        feature_dict = {
            'sepal length (cm)': N,
            'sepal width (cm)': N,
            'petal length (cm)': N,
            'petal width (cm)': N,
        }
        features = df[list(feature_dict.keys())]
        feat_type = list(feature_dict.values())
        labels = df[label_name]
        X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'])

# %%
y_train
# Out:
# array([0, 1, 2, 2, 0, 1, 1, 2, 1, 0, 0, 2, 2, 2, 0, 1, 1, 1, 1, 1, 2, 2,
#        0, 1, 1, 2, 0, 0, 2, 0, 0, 2, 0, 0, 1, 0, 1, 2, 1, 1, 1, 0, 2, 0,
#        0, 2, 0, 1, 0, 0, 2, 1, 0, 2, 0, 2, 2, 1, 1, 0, 0, 1, 1, 0, 2, 1,
#        1, 0, 2, 0, 0, 2, 0, 1, 1, 2, 2, 2, 1, 0, 1, 0, 1, 2, 2, 2, 0, 2,
#        2, 0, 1, 2, 1, 0, 2, 2, 2, 2, 2, 0, 1, 1, 0, 1, 2, 2, 1, 1, 1, 2,
#        0, 2])

# %%
automl.fit(X_train.copy(), y_train.copy(), feat_type=feat_type, dataset_name='Iris')

# %%
predictions = automl.predict(X_test)

# %%
predictions = automl.predict(X_test)
print("Accuracy score", sklearn.metrics.accuracy_score(y_test, predictions)*100)
# Out:
# Accuracy score 100.0

# %%
type(automl.show_models())
# Out:
# str

# %%
# Out:
# ['[',
#  '(',
#  '0',
#  '.',
#  '4',
#  '2',
#  '0',
#  '0',
#  '0',
#  '0',
#  ',',
#  ' ',
#  'S',
#  'i',
#  'm',
#  'p',
#  'l',
#  'e',
#  'C',
#  'l',
#  'a',
#  's',
#  's',
#  'i',
#  'f',
#  'i',
#  'c',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'P',
#  'i',
#  'p',
#  'e',
#  'l',
#  'i',
#  'n',
#  'e',
#  '(',
#  '{',
#  "'",
#  'b',
#  'a',
#  'l',
#  'a',
#  'n',
#  'c',
#  'i',
#  'n',
#  'g',
#  ':',
#  's',
#  't',
#  'r',
#  'a',
#  't',
#  'e',
#  'g',
#  'y',
#  "'",
#  ':',
#  ' ',
#  "'",
#  'w',
#  'e',
#  'i',
#  'g',
#  'h',
#  't',
#  'i',
#  'n',
#  'g',
#  "'",
#  ',',
#  ' ',
#  "'",
#  'c',
#  'a',
#  't',
#  'e',
#  'g',
#  'o',
#  'r',
#  'i',
#  'c',
#  'a',
#  'l',
#  '_',
#  'e',
#  'n',
#  'c',
#  'o',
#  'd',
#  'i',
#  'n',
#  'g',
#  ':',
#  '_',
#  '_',
#  'c',
#  'h',
#  'o',
#  'i',
#  'c',
#  'e',
#  '_',
#  '_',
#  "'",
#  ':',
#  ' ',
#  "'",
#  'o',
#  'n',
#  'e',
#  '_',
#  'h',
#  'o',
#  't',
#  '_',
#  'e',
#  'n',
#  'c',
#  'o',
# ...

# %%
import pickle
filename = "automodel_iris.sav"
pickle.dump(automl, open(filename, "wb"))

# %%
loaded_model = pickle.load(open(filename, "rb"))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 1.0

# %%
loaded_model.show_models()
# Out:
# "[(0.420000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'extra_trees', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'fast_ica', 'rescaling:__choice__': 'robust_scaler', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'False', 'classifier:extra_trees:bootstrap': 'False', 'classifier:extra_trees:criterion': 'gini', 'classifier:extra_trees:max_depth': 'None', 'classifier:extra_trees:max_features': 0.609975998293528, 'classifier:extra_trees:max_leaf_nodes': 'None', 'classifier:extra_trees:min_impurity_decrease': 0.0, 'classifier:extra_trees:min_samples_leaf': 1, 'classifier:extra_trees:min_samples_split': 2, 'classifier:extra_trees:min_weight_fraction_leaf': 0.0, 'classifier:extra_trees:n_estimators': 100, 'preprocessor:fast_ica:algorithm': 'parallel', 'preprocessor:fast_ica:fun': 'logcosh', 'preprocessor:fast_ica:whiten': 'True', 'rescaling:robust_sca
# ...
